# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
MyDataset = pd.read_csv('Dataset.csv')
MyDataset
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
MyDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
print('Data Duplikat : ', MyDataset.duplicated().sum())
# Out:
# Data Duplikat :  0

# %%
round((MyDataset.isnull().sum()))
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
describe = MyDataset.describe().T
describe
# Out:
#                           count        mean           std        min  \
# Unit price               1000.0   55.672130  2.649463e+01  10.080000
# Quantity                 1000.0    5.510000  2.923431e+00   1.000000
# Tax 5%                   1000.0   15.379369  1.170883e+01   0.508500
# Total                    1000.0  322.966749  2.458853e+02  10.678500
# cogs                     1000.0  307.587380  2.341765e+02  10.170000
# gross margin percentage  1000.0    4.761905  6.220360e-14   4.761905
# gross income             1000.0   15.379369  1.170883e+01   0.508500
# Rating                   1000.0    6.972700  1.718580e+00   4.000000
#
#                                 25%         50%         75%          max
# Unit price                32.875000   55.230000   77.935000    99.960000
# Quantity                   3.000000    5.000000    8.000000    10.000000
# Tax 5%                     5.924875   12.088000   22.445250    49.650000
# ...

# %%
MyDataset['City'].describe()
# Out:
# count       1000
# unique         3
# top       Yangon
# freq         340
# Name: City, dtype: object

# %%
MyDataset.shape #Mengetahui jumlah baris dan kolom
# Out:
# (1000, 17)

# %%
MyDataset.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
MyDataset.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
#Ubah type data date dari object ke datetime
MyDataset['Date'] = pd.to_datetime(MyDataset['Date'])
MyDataset['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
MyDataset.set_index('Date',inplace =True)

# %%
MyDataset.head(5)
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155  340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880  489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085  634.3785
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %%
MyDataset.tail(5)
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-29  233-67-5758      C  Naypyitaw        Normal    Male
# 2019-03-02  303-96-2227      B   Mandalay        Normal  Female
# 2019-02-09  727-02-1313      A     Yangon        Member    Male
# 2019-02-22  347-56-2442      A     Yangon        Normal    Male
# 2019-02-18  849-09-3807      A     Yangon        Member  Female
#
#                    Product line  Unit price  Quantity   Tax 5%      Total  \
# Date
# 2019-01-29    Health and beauty       40.35         1   2.0175    42.3675
# 2019-03-02   Home and lifestyle       97.38        10  48.6900  1022.4900
# 2019-02-09   Food and beverages       31.84         1   1.5920    33.4320
# 2019-02-22   Home and lifestyle       65.82         1   3.2910    69.1110
# 2019-02-18  Fashion accessories       88.34         7  30.9190   649.2990
#
#              Time  Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %%
MyDataset['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
index_price = MyDataset['City'] == 3

# %%
City = MyDataset[index_price]

# %%
City['City'].unique()
# Out:
# array([], dtype=object)

# %%
import seaborn as sns

sns.set()

sns.swarmplot(x='City', y='Rating', data=MyDataset)
plt.xlabel('City')
# Out:
# Text(0.5, 0, 'City')

# %%
plt.hist(MyDataset['City'])
plt.xlabel('Kota')
plt.ylabel('Frekuensi belanja')
# Out:
# Text(0, 0.5, 'Frekuensi belanja')

# %%
apply = MyDataset['City'].value_counts().reset_index()
apply
# Out:
#        index  City
# 0     Yangon   340
# 1   Mandalay   332
# 2  Naypyitaw   328

# %%
sns.regplot(x='Tax 5%',y='gross income',data=MyDataset,color='Red')
plt.xlabel('Pajak 5%')
plt.ylabel('Pendapatan Kotor')
plt.show()

# %%
sns.distplot(MyDataset['Rating'],kde=False)
plt.show()

# %%
MyDataset.hist(figsize=(12,12))
plt.show()

# %%
sns.countplot(MyDataset['Branch'])
plt.xlabel('Nama Branch')
plt.ylabel('Frekuensi')
plt.title('Branch yang paling banyak dikunjungi')
A,B,C =MyDataset.Branch.value_counts()
plt.savefig('report_Branch.png')

print('Branch A -',A)
print('Branch B -',C)
print('Branch C -',B)
      

plt.show()
# Out:
# Branch A - 340
# Branch B - 328
# Branch C - 332

# %%
sns.countplot(MyDataset['Payment'])
plt.xlabel('Cara Pembayaran')
plt.ylabel('Frekuensi')
plt.title('Diagram Metode Pembayaran yang sering digunakan')
A,B,C =MyDataset.Payment.value_counts()
plt.savefig('report_Payment.png')

print('E-wallet -',A)
print('Cash -',B)
print('Credit Card -',C)
plt.show()
# Out:
# E-wallet - 345
# Cash - 344
# Credit Card - 311

# %%
sns.countplot(MyDataset['Gender'])
plt.xlabel('Gender')
plt.ylabel('Frekuensi')
plt.title('Frekuensi Paling sering berbelanja berdasarkan Jenis Kelamin')
A,B =MyDataset.Gender.value_counts()
plt.savefig('report_Gender.png')

print('Laki-laki -',B)
print('Perempuan -',A)

plt.show()
# Out:
# Laki-laki - 499
# Perempuan - 501

# %%
sns.countplot(MyDataset['Customer type'])
plt.xlabel('Level Customer')
plt.ylabel('Frekuensi')
plt.title('Frekuensi pembelian tiap customer berdasarkan Level')
plt.savefig('report_Type.png')

plt.show()

# %%
sns.countplot(y ='Product line', hue = "Gender", data = MyDataset) 
plt.xlabel('Frekuensi')
plt.ylabel('Tipe Produk')
plt.savefig('report_ProdukGender.png')
plt.show()

# %%
sns.countplot(y ='Product line', hue = "City", data = MyDataset) 
plt.xlabel('Frekuensi')
plt.ylabel('Tipe Produk')
plt.savefig('report_ProdukCity.png')
plt.show()

# %%
sns.countplot(y ='Product line', hue = "Payment", data = MyDataset) 
plt.xlabel('Frekuensi')
plt.ylabel('Tipe Produk')
plt.savefig('report_ProdukPayment.png')
plt.show()

# %%
sns.countplot(x='Customer type', hue='Branch', data=MyDataset)
plt.xlabel('Branch')
plt.ylabel('Frekuensi')
plt.savefig('report_ProdukBranch.png')
plt.show()
